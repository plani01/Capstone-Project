# %%
import numpy as np
import os
from PIL import Image, ImageDraw
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

from sklearn.model_selection import train_test_split
#from sklearn.pipeline import Pipeline
#from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_curve, classification_report

import tensorflow as tf
from tensorflow import keras

# %%
def Create_Data_Matrix(directory):
    i=0
    for file in os.listdir(directory):
        filename = directory+'/'+file

        # Loads image, converts to grayscale and resizes it to a 300x300 image
        y = np.array(Image.open(filename).convert('RGB').resize((300,300)))

        #Resizes 300x300 image to 90,000x1 array
        col_y = y.ravel()[:,np.newaxis]

        # Saves
        if i==0:
            data = col_y
            #data = y
        else:
            data = np.hstack((data, col_y))
            #data = np.hstack((data, y))

        # Plots image
        """
        plt.figure(figsize=(5,5))
        plt.imshow(y, cmap='gray')
        plt.xticks([]),plt.yticks([])
        plt.show();
        """
        i+=1
        
    return data

# %%
def Resize_Before_Training(flattened):
    i = 0
    for x in flattened:
        temp = x.reshape((1,300,300,3))
    
        if i < 10:    
            plt.figure(figsize=(5,5))
            plt.imshow(temp[0], cmap='gray') # temp[0] to actually get img
            plt.xticks([]),plt.yticks([])
            plt.show();
    
        if i == 0:
            data = temp
        else:
            data = np.vstack((data,temp))
    
        i+=1
    
    return data

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
"""Creating the data matrix (ON HIPER-GATOR)"""

lighter_pics_HP = r"../../ExperimentPicsCollection/webCam/lighterImages"
lighter_pics2_HP = r"../../ExperimentPicsCollection/webCam/lighterImages2"
emptyClass_pics_HP = r"../../ExperimentPicsCollection/webCam/empty"


lighter_array = Create_Data_Matrix(lighter_pics_HP)
lighter_array2 = Create_Data_Matrix(lighter_pics2_HP)
emptyClass_array = Create_Data_Matrix(emptyClass_pics_HP)

# %%
print("lighter array size:",lighter_array.shape)
print("lighter array2 size:",lighter_array2.shape)
print("empty class array size",emptyClass_array.shape)
# Out:
# lighter array size: (270000, 152)
# lighter array2 size: (270000, 77)
# empty class array size (270000, 271)

# %%
lighter_together = np.hstack((lighter_array, lighter_array2))
lighter_together.shape
# Out:
# (270000, 229)

# %%
"""X : FEATURE MATRIX For CLASSIFICATION""" 

# stack all arrays together
X = np.hstack((lighter_together,emptyClass_array)).T

X.shape
# Out:
# (500, 270000)

# %%
t = np.hstack(( 1*np.ones(lighter_together.shape[1]),np.zeros(emptyClass_array.shape[1]))).T

t.shape
# Out:
# (500,)

# %%
"""Train Test Split for Feature Matrix"""
#X =X/255.
 
X_train, X_test, t_train, t_test = train_test_split(X, t, test_size=0.2, random_state=42, stratify=t)

X_train.shape, X_test.shape, t_train.shape, t_test.shape
# Out:
# ((400, 270000), (100, 270000), (400,), (100,))

# %%
X_train_R = Resize_Before_Training(X_train)

# %%
X_test_R = Resize_Before_Training(X_test)

# %%
plt.figure(figsize=(10, 10))
index = 10
for i in range(9):
    #augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_test_R[index + i].astype("uint8"))
    plt.xlabel("Label: "+ str(t_test[index + i]) )
    #plt.axis("off")

# %%
img_height = 300
img_width = 300
batch_size = 32

# %%
data_augmentation = keras.Sequential(
  [
    keras.layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,img_width,3)),
    keras.layers.RandomRotation(factor=0.15),
    keras.layers.RandomZoom(height_factor=0.1),
    keras.layers.RandomContrast((0.3,0.1))
    
  ]
)
# Out:
# 2023-10-30 16:21:24.441765: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 16:21:25.329869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78911 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:07:00.0, compute capability: 8.0

# %%
model = keras.models.Sequential([
    data_augmentation,
    keras.layers.Rescaling(1./255),
    #keras.layers.Conv2D(4, 7, activation='relu', padding='same' , input_shape=[300, 300, 3]), 
    keras.layers.Conv2D(4, 7, activation='relu', padding='same'), 
    keras.layers.MaxPooling2D(2), # experiment to maybe remove
    keras.layers.Conv2D(8, 8, activation='relu', padding='same'), 
    keras.layers.MaxPooling2D(2), 
    keras.layers.Flatten(), # Why do a flatten here? Need to flatne back to 1-D MLP layer?
    # starting MLP layer
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(2, activation='softmax')  #3 classes, get rid of softmax?( output function maybe want 0,1,2?)
])

# %%
model.compile(loss=keras.losses.sparse_categorical_crossentropy,   
             optimizer=keras.optimizers.Adam(learning_rate=0.001),
             metrics=['accuracy'])

# %%
epochs = 100

history = model.fit(X_train_R, t_train, epochs=epochs, batch_size=32,
         validation_data=(X_test_R, t_test))
# Out:
# Epoch 1/100
# 2023-10-30 16:21:27.524374: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8201
# 2023-10-30 16:21:29.240235: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 13/13 [==============================] - 4s 31ms/step - loss: 1.4818 - accuracy: 0.4975 - val_loss: 0.6950 - val_accuracy: 0.4600
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6903 - accuracy: 0.5625 - val_loss: 0.6861 - val_accuracy: 0.7200
# Epoch 3/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6932 - accuracy: 0.6225 - val_loss: 0.6903 - val_accuracy: 0.5400
# Epoch 4/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6872 - accuracy: 0.5425 - val_loss: 0.6807 - val_accuracy: 0.5400
# Epoch 5/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6809 - accuracy: 0.5475 - val_loss: 0.6732 - val_accuracy: 0.5400
# Epoch 6/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6760 - accuracy: 0.5425 - val_loss: 0.6524 - val_accuracy: 0.5400
# Epoch 7/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6449 - accuracy: 0.5525 - val_loss: 0.5848 - val_accuracy: 0.7500
# Epoch 8/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6139 - accuracy: 0.6800 - val_loss: 0.5403 - val_accuracy: 0.7400
# Epoch 9/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5891 - accuracy: 0.7000 - val_loss: 0.4300 - val_accuracy: 0.9100
# Epoch 10/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6625 - accuracy: 0.7250 - val_loss: 0.4139 - val_accuracy: 0.8900
# Epoch 11/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6262 - accuracy: 0.6550 - val_loss: 0.6544 - val_accuracy: 0.6200
# Epoch 12/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6795 - accuracy: 0.5500 - val_loss: 0.6691 - val_accuracy: 0.5600
# Epoch 13/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.6830 - accuracy: 0.5375 - val_loss: 0.6668 - val_accuracy: 0.5400
# Epoch 14/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6835 - accuracy: 0.5850 - val_loss: 0.6627 - val_accuracy: 0.5700
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6762 - accuracy: 0.5475 - val_loss: 0.6495 - val_accuracy: 0.5400
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6711 - accuracy: 0.5700 - val_loss: 0.6053 - val_accuracy: 0.6100
# Epoch 17/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6545 - accuracy: 0.6025 - val_loss: 0.6108 - val_accuracy: 0.6100
# Epoch 18/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6706 - accuracy: 0.6325 - val_loss: 0.5783 - val_accuracy: 0.8800
# Epoch 19/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6537 - accuracy: 0.5275 - val_loss: 0.6114 - val_accuracy: 0.5500
# Epoch 20/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6519 - accuracy: 0.6500 - val_loss: 0.5747 - val_accuracy: 0.5400
# Epoch 21/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6274 - accuracy: 0.6300 - val_loss: 0.5352 - val_accuracy: 0.9200
# Epoch 22/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6190 - accuracy: 0.6675 - val_loss: 0.4976 - val_accuracy: 0.8900
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5928 - accuracy: 0.7100 - val_loss: 0.4934 - val_accuracy: 0.8900
# Epoch 24/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5995 - accuracy: 0.6325 - val_loss: 0.4767 - val_accuracy: 0.8800
# Epoch 25/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5636 - accuracy: 0.7150 - val_loss: 0.4561 - val_accuracy: 0.8500
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5938 - accuracy: 0.6500 - val_loss: 0.4249 - val_accuracy: 0.9200
# Epoch 27/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5597 - accuracy: 0.7175 - val_loss: 0.3426 - val_accuracy: 0.9100
# Epoch 28/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5295 - accuracy: 0.7400 - val_loss: 0.3885 - val_accuracy: 0.9000
# Epoch 29/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5533 - accuracy: 0.7025 - val_loss: 1.1730 - val_accuracy: 0.5400
# Epoch 30/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6019 - accuracy: 0.6925 - val_loss: 0.3422 - val_accuracy: 0.9100
# Epoch 31/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5240 - accuracy: 0.7250 - val_loss: 0.3214 - val_accuracy: 0.9300
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4842 - accuracy: 0.7525 - val_loss: 0.2850 - val_accuracy: 0.9300
# Epoch 33/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4718 - accuracy: 0.7700 - val_loss: 0.2623 - val_accuracy: 0.9400
# Epoch 34/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.8047 - accuracy: 0.6750 - val_loss: 0.4211 - val_accuracy: 0.8800
# Epoch 35/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5395 - accuracy: 0.7375 - val_loss: 0.4208 - val_accuracy: 0.9000
# Epoch 36/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5237 - accuracy: 0.7500 - val_loss: 0.3993 - val_accuracy: 0.8900
# Epoch 37/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5026 - accuracy: 0.7700 - val_loss: 0.3664 - val_accuracy: 0.8800
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.6285 - accuracy: 0.7075 - val_loss: 0.3834 - val_accuracy: 0.8600
# Epoch 39/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5706 - accuracy: 0.6975 - val_loss: 0.4315 - val_accuracy: 0.8900
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5667 - accuracy: 0.7050 - val_loss: 0.4217 - val_accuracy: 0.8900
# Epoch 41/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5301 - accuracy: 0.7200 - val_loss: 0.3794 - val_accuracy: 0.8900
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5319 - accuracy: 0.7350 - val_loss: 0.3588 - val_accuracy: 0.8900
# Epoch 43/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5409 - accuracy: 0.7525 - val_loss: 0.4212 - val_accuracy: 0.8100
# Epoch 44/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5581 - accuracy: 0.6850 - val_loss: 0.4127 - val_accuracy: 0.8900
# Epoch 45/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5642 - accuracy: 0.7050 - val_loss: 0.4145 - val_accuracy: 0.9100
# Epoch 46/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5438 - accuracy: 0.7275 - val_loss: 0.3402 - val_accuracy: 0.9400
# Epoch 47/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5105 - accuracy: 0.7475 - val_loss: 0.3248 - val_accuracy: 0.9000
# Epoch 48/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5370 - accuracy: 0.7425 - val_loss: 0.3591 - val_accuracy: 0.9000
# Epoch 49/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5085 - accuracy: 0.7625 - val_loss: 0.3451 - val_accuracy: 0.9200
# Epoch 50/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5197 - accuracy: 0.7300 - val_loss: 0.3349 - val_accuracy: 0.8800
# Epoch 51/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5119 - accuracy: 0.7350 - val_loss: 0.3264 - val_accuracy: 0.9700
# Epoch 52/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4913 - accuracy: 0.7675 - val_loss: 0.3276 - val_accuracy: 0.8800
# Epoch 53/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4964 - accuracy: 0.7225 - val_loss: 0.3682 - val_accuracy: 0.8800
# Epoch 54/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5095 - accuracy: 0.7425 - val_loss: 0.3218 - val_accuracy: 0.9200
# Epoch 55/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5308 - accuracy: 0.7350 - val_loss: 0.2874 - val_accuracy: 0.9500
# Epoch 56/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5261 - accuracy: 0.7275 - val_loss: 0.3034 - val_accuracy: 0.9400
# Epoch 57/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4900 - accuracy: 0.7625 - val_loss: 0.3470 - val_accuracy: 0.8700
# Epoch 58/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5016 - accuracy: 0.7350 - val_loss: 0.3483 - val_accuracy: 0.9000
# Epoch 59/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4528 - accuracy: 0.7900 - val_loss: 0.2951 - val_accuracy: 0.9300
# Epoch 60/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5076 - accuracy: 0.7850 - val_loss: 0.4697 - val_accuracy: 0.7400
# Epoch 61/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4645 - accuracy: 0.7775 - val_loss: 0.3937 - val_accuracy: 0.8700
# Epoch 62/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5042 - accuracy: 0.7850 - val_loss: 0.3705 - val_accuracy: 0.8800
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5037 - accuracy: 0.7625 - val_loss: 0.3247 - val_accuracy: 0.9000
# Epoch 64/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4701 - accuracy: 0.7750 - val_loss: 0.2851 - val_accuracy: 0.9200
# Epoch 65/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.4791 - accuracy: 0.7600 - val_loss: 0.3387 - val_accuracy: 0.8600
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4249 - accuracy: 0.8050 - val_loss: 0.3233 - val_accuracy: 0.9200
# Epoch 67/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4442 - accuracy: 0.7800 - val_loss: 0.3152 - val_accuracy: 0.9200
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3964 - accuracy: 0.8000 - val_loss: 0.3197 - val_accuracy: 0.9200
# Epoch 69/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3985 - accuracy: 0.8075 - val_loss: 0.3109 - val_accuracy: 0.9300
# Epoch 70/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4334 - accuracy: 0.7725 - val_loss: 0.3060 - val_accuracy: 0.9100
# Epoch 71/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3588 - accuracy: 0.8200 - val_loss: 0.3393 - val_accuracy: 0.9100
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3028 - accuracy: 0.8600 - val_loss: 0.2125 - val_accuracy: 0.9300
# Epoch 73/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3353 - accuracy: 0.8450 - val_loss: 0.2072 - val_accuracy: 0.9200
# Epoch 74/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3290 - accuracy: 0.8550 - val_loss: 0.4074 - val_accuracy: 0.9300
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3044 - accuracy: 0.8325 - val_loss: 0.2998 - val_accuracy: 0.9300
# Epoch 76/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2607 - accuracy: 0.8700 - val_loss: 0.1211 - val_accuracy: 0.9400
# Epoch 77/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2742 - accuracy: 0.8800 - val_loss: 0.1770 - val_accuracy: 0.9000
# Epoch 78/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2916 - accuracy: 0.9075 - val_loss: 0.1072 - val_accuracy: 0.9400
# Epoch 79/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2448 - accuracy: 0.8975 - val_loss: 0.1122 - val_accuracy: 0.9600
# Epoch 80/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2585 - accuracy: 0.9100 - val_loss: 0.1395 - val_accuracy: 0.9500
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2567 - accuracy: 0.9075 - val_loss: 0.0932 - val_accuracy: 0.9700
# Epoch 82/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2432 - accuracy: 0.9000 - val_loss: 0.1312 - val_accuracy: 0.9400
# Epoch 83/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2750 - accuracy: 0.9025 - val_loss: 0.1123 - val_accuracy: 0.9500
# Epoch 84/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2405 - accuracy: 0.9325 - val_loss: 0.0994 - val_accuracy: 0.9800
# Epoch 85/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2170 - accuracy: 0.9275 - val_loss: 0.1237 - val_accuracy: 0.9500
# Epoch 86/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2113 - accuracy: 0.9225 - val_loss: 0.0965 - val_accuracy: 0.9600
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2003 - accuracy: 0.9250 - val_loss: 0.1178 - val_accuracy: 0.9400
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2439 - accuracy: 0.8925 - val_loss: 0.1536 - val_accuracy: 0.9500
# Epoch 89/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2877 - accuracy: 0.8925 - val_loss: 0.1256 - val_accuracy: 0.9600
# Epoch 90/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2780 - accuracy: 0.9025 - val_loss: 0.1013 - val_accuracy: 0.9600
# Epoch 91/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2266 - accuracy: 0.9375 - val_loss: 0.1124 - val_accuracy: 0.9600
# Epoch 92/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2143 - accuracy: 0.9350 - val_loss: 0.1083 - val_accuracy: 0.9600
# Epoch 93/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1810 - accuracy: 0.9325 - val_loss: 0.1069 - val_accuracy: 0.9600
# Epoch 94/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1751 - accuracy: 0.9400 - val_loss: 0.1130 - val_accuracy: 0.9500
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1798 - accuracy: 0.9400 - val_loss: 0.1459 - val_accuracy: 0.9500
# Epoch 96/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2109 - accuracy: 0.9050 - val_loss: 0.1162 - val_accuracy: 0.9500
# Epoch 97/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2239 - accuracy: 0.9300 - val_loss: 0.1245 - val_accuracy: 0.9600
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1937 - accuracy: 0.9250 - val_loss: 0.1171 - val_accuracy: 0.9500
# Epoch 99/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1772 - accuracy: 0.9375 - val_loss: 0.1258 - val_accuracy: 0.9600
# Epoch 100/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1968 - accuracy: 0.9250 - val_loss: 0.1133 - val_accuracy: 0.9600

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
y_train = np.argmax(model.predict(X_train_R),axis=1)
y_test = np.argmax(model.predict(X_test_R),axis=1)

# %%
print(classification_report(t_train, y_train))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.98      0.95       217
#          1.0       0.97      0.91      0.94       183
#
#     accuracy                           0.95       400
#    macro avg       0.95      0.94      0.95       400
# weighted avg       0.95      0.95      0.95       400

# %%
print(classification_report(t_test, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.96        54
#          1.0       0.98      0.93      0.96        46
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100

# %%
print(confusion_matrix(t_test, y_test))
# Out:
# [[53  1]
#  [ 3 43]]

# %%
"""Storing Model in Keras format"""
model.save('webCamPics.keras')
